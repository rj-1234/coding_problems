# %%
import pandas as pd
import numpy as np
import nltk
import re

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import collections
import random
from tqdm import tqdm

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.test.utils import common_texts, get_tmpfile
from gensim.utils import simple_preprocess
from gensim.models.callbacks import CallbackAny2Vec

from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import utils
from sklearn.model_selection import train_test_split

import csv

import multiprocessing
# Out:
# 2020-12-22 20:01:21,249 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2020-12-22 20:01:21,252 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)

# %%
from collections import namedtuple

class TaggedDocumentNew(namedtuple('TaggedDocument', 'words tags rating id')):
    """Represents a document along with a tag, input document format for :class:`~gensim.models.doc2vec.Doc2Vec`.
    A single document, made up of `words` (a list of unicode string tokens) and `tags` (a list of tokens).
    Tags may be one or more unicode string tokens, but typical practice (which will also be the most memory-efficient)
    is for the tags list to include a unique integer id as the only tag.
    Replaces "sentence as a list of words" from :class:`gensim.models.word2vec.Word2Vec`.
    """
    def __str__(self):
        """Human readable representation of the object's state, used for debugging.
        Returns
        -------
        str
           Human readable representation of the object's state (words and tags).
        """
        return '%s(%s, %s)' % (self.__class__.__name__, self.words, self.tags, self.rating, self.id)

# %% [markdown]
# #### DATA

# %%
from os import listdir
from os.path import isfile, join

path_pos = "./Data/raw/aclImdb_v1/aclImdb/train/pos/"
pos_rev_files = ["pos/"+f for f in listdir(path_pos) if isfile(join(path_pos, f))]

path_neg = "./Data/raw/aclImdb_v1/aclImdb/train/neg/"
neg_rev_files = ["neg/"+f for f in listdir(path_neg) if isfile(join(path_neg, f))]

path_unsup = "./Data/raw/aclImdb_v1/aclImdb/train/unsup/"
unsup_rev_files = ["unsup/"+f for f in listdir(path_unsup) if isfile(join(path_unsup, f))]

# %%
def generate_review_df(files, url_file):
    base_path = "./Data/raw/aclImdb_v1/aclImdb/train/"
    
    df = pd.DataFrame(columns=["id", "rating", "review", "title"])
    with open(url_file, "r") as file:
        urls = file.readlines()

    for file in tqdm(files):
        _id = file.split("_")[0].split("/")[-1]
        _rating = file.split("_")[-1].split(".")[0]
        with open (base_path+file, "r", encoding="utf8") as f:
            _review = f.readline()
            
        _title = urls[int(_id)].split("/")[-2]
        temp = pd.DataFrame(data=[[_id, _rating, _review, _title]], columns=["id", "rating", "review", "title"])
        df = pd.concat([df, temp], axis=0)
        
    return df

# %%
df_pos = generate_review_df(pos_rev_files, "./Data/raw/aclImdb_v1/aclImdb/train/urls_pos.txt")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 12500/12500 [00:15<00:00, 811.18it/s]

# %%
df_neg = generate_review_df(neg_rev_files, "./Data/raw/aclImdb_v1/aclImdb/train/urls_neg.txt")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 12500/12500 [00:14<00:00, 845.56it/s]

# %%
df = pd.concat([df_pos, df_neg], axis=0).reset_index().drop(["index"], axis=1)

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.shape
# Out:
# (25000, 4)

# %%
X = df.loc[:, ["review", "id"]]
y = df.loc[:, ["rating"]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
df.to_csv("./Data/transformed/data.csv", index=False, header=False, sep="\t")

# %%
train = pd.concat([X_train, y_train], axis=1)
test = pd.concat([X_test, y_test], axis=1)

# %%
train.to_csv("./Data/transformed/data_train.csv", index=False, header=False, sep="\t")

# %%
test.to_csv("./Data/transformed/data_test.csv", index=False, header=False, sep="\t")

# %%
import smart_open

def preprocess(line):
    contents = line.split("\t")
    text = contents[0].strip()
    tokens = word_tokenize(text)
    tokens = [t.lower() for t in tokens]
    table = str.maketrans('', '', string.punctuation)
    stripped = [w.translate(table) for w in tokens]
    words = [word for word in stripped if word.isalpha()]
    stop_words = set(stopwords.words('english') + ["br"])
    words = [w for w in words if w not in stop_words and len(w) > 2]
    return contents[1].strip(), contents[2].strip(), words

def read_corpus(fname, tokens_only=False):
    with smart_open.open(fname, encoding="iso-8859-1") as f:
        for i, line in tqdm(enumerate(f)):
            _id, rating, tokens = preprocess(line)
            if tokens_only:
                yield tokens
            else:
                # For training data, add tags
                yield TaggedDocumentNew(tokens, [i], [rating], [_id])

train_corpus = list(read_corpus('./Data/transformed/data_train.csv'))
test_corpus = list(read_corpus('./Data/transformed/data_test.csv'))
# Out:
# 16750it [00:30, 552.34it/s]
# 8250it [00:14, 562.40it/s]

# %%
train_corpus[3]
# Out:
# TaggedDocumentNew(words=['one', 'thing', 'recommend', 'film', 'intriguing', 'premise', 'certainly', 'draws', 'audience', 'mystery', 'throughout', 'film', 'hints', 'something', 'dark', 'lurking', 'however', 'much', 'tension', 'williams', 'mild', 'mannered', 'portrayal', 'much', 'makes', 'relate', 'obsession', 'boy', 'collete', 'fares', 'much', 'better', 'woman', 'whose', 'true', 'nature', 'intentions', 'clear', 'production', 'felt', 'rushed', 'holes', 'apparent', 'certainly', 'feels', 'like', 'preview', 'much', 'complete', 'better', 'effort', 'book', 'probably', 'better', 'one', 'thing', 'certain', 'taupin', 'must', 'written', 'something', 'truly', 'good', 'inspired', 'least', 'one', 'commendable', 'effort'], tags=[3], rating=['8'], id=['10016'])

# %%
cores = multiprocessing.cpu_count()

model = Doc2Vec(vector_size=300, min_count=2, epochs=50, workers=cores)
model.build_vocab([x for x in tqdm(train_corpus)])
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 16750/16750 [00:00<00:00, 2417570.27it/s]
# 2020-12-22 20:25:09,438 : INFO : collecting all words and their counts
# 2020-12-22 20:25:09,438 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2020-12-22 20:25:09,652 : INFO : PROGRESS: at example #10000, processed 1151758 words (5419560/s), 58631 word types, 10000 tags
# 2020-12-22 20:25:09,799 : INFO : collected 75711 word types and 16750 unique tags from a corpus of 16750 examples and 1951575 words
# 2020-12-22 20:25:09,800 : INFO : Loading a fresh vocabulary
# 2020-12-22 20:25:09,866 : INFO : effective_min_count=2 retains 41041 unique words (54% of original 75711, drops 34670)
# 2020-12-22 20:25:09,867 : INFO : effective_min_count=2 leaves 1916905 word corpus (98% of original 1951575, drops 34670)
# 2020-12-22 20:25:09,980 : INFO : deleting the raw counts dictionary of 75711 items
# 2020-12-22 20:25:09,982 : INFO : sample=0.001 downsamples 24 most-common words
# 2020-12-22 20:25:09,983 : INFO : downsampling leaves estimated 1837932 word corpus (95.9% of prior 1916905)
# 2020-12-22 20:25:10,089 : INFO : estimated required memory for 41041 words and 300 dimensions: 139118900 bytes
# 2020-12-22 20:25:10,090 : INFO : resetting layer weights

# %%
model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# 2020-12-22 20:27:08,649 : INFO : training model with 12 workers on 41041 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2020-12-22 20:27:09,681 : INFO : EPOCH 1 - PROGRESS: at 9.86% examples, 185027 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:10,688 : INFO : EPOCH 1 - PROGRESS: at 20.23% examples, 185919 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:11,693 : INFO : EPOCH 1 - PROGRESS: at 42.42% examples, 258442 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:12,706 : INFO : EPOCH 1 - PROGRESS: at 66.10% examples, 300995 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:13,709 : INFO : EPOCH 1 - PROGRESS: at 87.91% examples, 323276 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:13,986 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:14,000 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:14,028 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:14,037 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:14,045 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:14,054 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:14,061 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:14,091 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:14,095 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:14,102 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:14,107 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:14,111 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:14,111 : INFO : EPOCH - 1 : training on 1951575 raw words (1854872 effective words) took 5.4s, 340522 effective words/s
# 2020-12-22 20:27:15,149 : INFO : EPOCH 2 - PROGRESS: at 20.17% examples, 365038 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:16,169 : INFO : EPOCH 2 - PROGRESS: at 39.82% examples, 358754 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:17,221 : INFO : EPOCH 2 - PROGRESS: at 62.15% examples, 367944 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:18,223 : INFO : EPOCH 2 - PROGRESS: at 83.91% examples, 379032 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:18,758 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:18,772 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:18,795 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:18,810 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:18,813 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:18,816 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:18,830 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:18,866 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:18,869 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:18,875 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:18,878 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:18,884 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:18,885 : INFO : EPOCH - 2 : training on 1951575 raw words (1854441 effective words) took 4.8s, 389117 effective words/s
# 2020-12-22 20:27:19,964 : INFO : EPOCH 3 - PROGRESS: at 18.72% examples, 325164 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:20,964 : INFO : EPOCH 3 - PROGRESS: at 40.88% examples, 364427 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:21,975 : INFO : EPOCH 3 - PROGRESS: at 62.65% examples, 373681 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:22,978 : INFO : EPOCH 3 - PROGRESS: at 82.90% examples, 376458 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:23,546 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:23,565 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:23,572 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:23,588 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:23,594 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:23,600 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:23,616 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:23,639 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:23,641 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:23,647 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:23,651 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:23,662 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:23,662 : INFO : EPOCH - 3 : training on 1951575 raw words (1854799 effective words) took 4.8s, 388990 effective words/s
# 2020-12-22 20:27:24,682 : INFO : EPOCH 4 - PROGRESS: at 10.95% examples, 204598 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:25,691 : INFO : EPOCH 4 - PROGRESS: at 29.01% examples, 265988 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:26,704 : INFO : EPOCH 4 - PROGRESS: at 52.07% examples, 317299 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:27,720 : INFO : EPOCH 4 - PROGRESS: at 72.46% examples, 330829 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:28,734 : INFO : EPOCH 4 - PROGRESS: at 94.49% examples, 346447 words/s, in_qsize 11, out_qsize 1
# 2020-12-22 20:27:28,736 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:28,761 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:28,773 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:28,785 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:28,811 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:28,812 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:28,818 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:28,836 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:28,843 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:28,846 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:28,848 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:28,862 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:28,863 : INFO : EPOCH - 4 : training on 1951575 raw words (1854841 effective words) took 5.2s, 357283 effective words/s
# 2020-12-22 20:27:29,897 : INFO : EPOCH 5 - PROGRESS: at 18.72% examples, 339434 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:30,917 : INFO : EPOCH 5 - PROGRESS: at 43.44% examples, 392024 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:31,956 : INFO : EPOCH 5 - PROGRESS: at 68.08% examples, 406714 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:32,958 : INFO : EPOCH 5 - PROGRESS: at 90.83% examples, 413042 words/s, in_qsize 18, out_qsize 0
# 2020-12-22 20:27:33,182 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:33,187 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:33,205 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:33,217 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:33,225 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:33,237 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:33,244 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:33,264 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:33,269 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:33,274 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:33,276 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:33,288 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:33,290 : INFO : EPOCH - 5 : training on 1951575 raw words (1854381 effective words) took 4.4s, 419821 effective words/s
# 2020-12-22 20:27:34,356 : INFO : EPOCH 6 - PROGRESS: at 18.72% examples, 328849 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:35,420 : INFO : EPOCH 6 - PROGRESS: at 43.44% examples, 377990 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:36,423 : INFO : EPOCH 6 - PROGRESS: at 67.64% examples, 398547 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:37,446 : INFO : EPOCH 6 - PROGRESS: at 88.39% examples, 395549 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:37,731 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:37,741 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:37,754 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:37,767 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:37,785 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:37,793 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:37,804 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:37,842 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:37,844 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:37,845 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:37,850 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:37,859 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:37,860 : INFO : EPOCH - 6 : training on 1951575 raw words (1854707 effective words) took 4.6s, 406582 effective words/s
# 2020-12-22 20:27:38,949 : INFO : EPOCH 7 - PROGRESS: at 18.72% examples, 322331 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:39,996 : INFO : EPOCH 7 - PROGRESS: at 39.82% examples, 346082 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:41,066 : INFO : EPOCH 7 - PROGRESS: at 62.15% examples, 357091 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:42,066 : INFO : EPOCH 7 - PROGRESS: at 84.47% examples, 372954 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:42,595 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:42,613 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:42,620 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:42,640 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:42,647 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:42,651 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:42,656 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:42,699 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:42,702 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:42,704 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:42,704 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:42,713 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:42,713 : INFO : EPOCH - 7 : training on 1951575 raw words (1854797 effective words) took 4.8s, 382880 effective words/s
# 2020-12-22 20:27:43,734 : INFO : EPOCH 8 - PROGRESS: at 7.02% examples, 129894 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:44,742 : INFO : EPOCH 8 - PROGRESS: at 22.30% examples, 205057 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:45,788 : INFO : EPOCH 8 - PROGRESS: at 37.37% examples, 224477 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:46,807 : INFO : EPOCH 8 - PROGRESS: at 55.18% examples, 249414 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:47,832 : INFO : EPOCH 8 - PROGRESS: at 76.08% examples, 274977 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:48,690 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:48,701 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:48,714 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:48,720 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:48,725 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:48,734 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:48,740 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:48,765 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:48,772 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:48,775 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:48,781 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:48,792 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:48,792 : INFO : EPOCH - 8 : training on 1951575 raw words (1854520 effective words) took 6.1s, 305570 effective words/s
# 2020-12-22 20:27:49,835 : INFO : EPOCH 9 - PROGRESS: at 18.72% examples, 336513 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:27:50,850 : INFO : EPOCH 9 - PROGRESS: at 38.84% examples, 349812 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:51,850 : INFO : EPOCH 9 - PROGRESS: at 60.60% examples, 365051 words/s, in_qsize 22, out_qsize 0
# 2020-12-22 20:27:52,895 : INFO : EPOCH 9 - PROGRESS: at 81.42% examples, 368481 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:53,455 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:53,478 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:53,492 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:53,514 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:53,521 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:53,525 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:53,555 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:53,576 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:53,580 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:53,583 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:53,586 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:53,594 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:53,595 : INFO : EPOCH - 9 : training on 1951575 raw words (1854763 effective words) took 4.8s, 386867 effective words/s
# 2020-12-22 20:27:54,674 : INFO : EPOCH 10 - PROGRESS: at 12.48% examples, 219779 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:55,703 : INFO : EPOCH 10 - PROGRESS: at 32.17% examples, 283093 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:56,759 : INFO : EPOCH 10 - PROGRESS: at 55.66% examples, 326072 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:57,768 : INFO : EPOCH 10 - PROGRESS: at 79.43% examples, 353374 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:27:58,824 : INFO : EPOCH 10 - PROGRESS: at 93.39% examples, 332383 words/s, in_qsize 13, out_qsize 0
# 2020-12-22 20:27:58,922 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:27:58,969 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:27:58,978 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:27:58,994 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:27:59,017 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:27:59,036 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:27:59,052 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:27:59,122 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:27:59,129 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:27:59,135 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:27:59,138 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:27:59,154 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:27:59,156 : INFO : EPOCH - 10 : training on 1951575 raw words (1854956 effective words) took 5.6s, 334146 effective words/s
# 2020-12-22 20:28:00,189 : INFO : EPOCH 11 - PROGRESS: at 6.47% examples, 120393 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:01,271 : INFO : EPOCH 11 - PROGRESS: at 18.72% examples, 166048 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:02,336 : INFO : EPOCH 11 - PROGRESS: at 31.66% examples, 184768 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:03,346 : INFO : EPOCH 11 - PROGRESS: at 47.60% examples, 210245 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:04,363 : INFO : EPOCH 11 - PROGRESS: at 69.07% examples, 245385 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:05,389 : INFO : EPOCH 11 - PROGRESS: at 91.88% examples, 274578 words/s, in_qsize 16, out_qsize 0
# 2020-12-22 20:28:05,536 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:05,547 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:05,550 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:05,566 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:05,570 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:05,587 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:05,598 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:05,620 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:05,624 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:05,627 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:05,628 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:05,640 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:05,641 : INFO : EPOCH - 11 : training on 1951575 raw words (1854643 effective words) took 6.5s, 286830 effective words/s
# 2020-12-22 20:28:06,714 : INFO : EPOCH 12 - PROGRESS: at 18.72% examples, 326738 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:07,727 : INFO : EPOCH 12 - PROGRESS: at 42.95% examples, 381472 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:08,732 : INFO : EPOCH 12 - PROGRESS: at 62.15% examples, 370163 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:09,757 : INFO : EPOCH 12 - PROGRESS: at 85.45% examples, 385615 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:10,221 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:10,258 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:10,262 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:10,292 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:10,295 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:10,301 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:10,317 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:10,338 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:10,345 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:10,349 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:10,354 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:10,356 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:10,357 : INFO : EPOCH - 12 : training on 1951575 raw words (1855060 effective words) took 4.7s, 394016 effective words/s
# 2020-12-22 20:28:11,470 : INFO : EPOCH 13 - PROGRESS: at 18.72% examples, 314982 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:12,557 : INFO : EPOCH 13 - PROGRESS: at 43.44% examples, 366056 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:13,570 : INFO : EPOCH 13 - PROGRESS: at 67.16% examples, 385802 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:14,575 : INFO : EPOCH 13 - PROGRESS: at 88.00% examples, 387613 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:14,865 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:14,870 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:14,888 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:14,900 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:14,908 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:14,923 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:14,931 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:14,960 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:14,965 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:14,968 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:14,971 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:14,982 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:14,983 : INFO : EPOCH - 13 : training on 1951575 raw words (1854925 effective words) took 4.6s, 401784 effective words/s
# 2020-12-22 20:28:16,126 : INFO : EPOCH 14 - PROGRESS: at 12.48% examples, 207623 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:17,137 : INFO : EPOCH 14 - PROGRESS: at 36.27% examples, 312477 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:18,154 : INFO : EPOCH 14 - PROGRESS: at 56.20% examples, 328469 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:19,176 : INFO : EPOCH 14 - PROGRESS: at 78.91% examples, 349547 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:19,992 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:20,004 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:20,015 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:20,023 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:20,031 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:20,042 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:20,044 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:20,074 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:20,083 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:20,086 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:20,089 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:20,099 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:20,101 : INFO : EPOCH - 14 : training on 1951575 raw words (1854721 effective words) took 5.1s, 363304 effective words/s
# 2020-12-22 20:28:21,113 : INFO : EPOCH 15 - PROGRESS: at 18.73% examples, 346653 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:22,133 : INFO : EPOCH 15 - PROGRESS: at 41.43% examples, 377545 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:23,133 : INFO : EPOCH 15 - PROGRESS: at 62.15% examples, 377438 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:24,170 : INFO : EPOCH 15 - PROGRESS: at 84.92% examples, 387705 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:24,692 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:24,694 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:24,698 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:24,718 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:24,724 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:24,742 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:24,758 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:24,784 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:24,786 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:24,788 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:24,790 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:24,803 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:24,804 : INFO : EPOCH - 15 : training on 1951575 raw words (1854452 effective words) took 4.7s, 394995 effective words/s
# 2020-12-22 20:28:26,009 : INFO : EPOCH 16 - PROGRESS: at 18.72% examples, 291059 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:27,030 : INFO : EPOCH 16 - PROGRESS: at 39.82% examples, 331904 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:28,050 : INFO : EPOCH 16 - PROGRESS: at 61.67% examples, 349672 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:29,088 : INFO : EPOCH 16 - PROGRESS: at 81.89% examples, 355173 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:29,705 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:29,719 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:29,723 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:29,734 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:29,737 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:29,764 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:29,767 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:29,785 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:29,789 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:29,796 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:29,799 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:29,810 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:29,811 : INFO : EPOCH - 16 : training on 1951575 raw words (1854826 effective words) took 5.0s, 371064 effective words/s
# 2020-12-22 20:28:30,836 : INFO : EPOCH 17 - PROGRESS: at 13.44% examples, 249644 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:31,950 : INFO : EPOCH 17 - PROGRESS: at 37.37% examples, 323228 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:32,970 : INFO : EPOCH 17 - PROGRESS: at 55.18% examples, 323525 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:34,044 : INFO : EPOCH 17 - PROGRESS: at 67.64% examples, 294838 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:35,075 : INFO : EPOCH 17 - PROGRESS: at 79.90% examples, 281761 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:36,008 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:36,015 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:36,022 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:36,024 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:36,034 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:36,047 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:36,051 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:36,081 : INFO : EPOCH 17 - PROGRESS: at 98.03% examples, 290722 words/s, in_qsize 4, out_qsize 1
# 2020-12-22 20:28:36,082 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:36,086 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:36,090 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:36,093 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:36,100 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:36,101 : INFO : EPOCH - 17 : training on 1951575 raw words (1854986 effective words) took 6.3s, 295331 effective words/s
# 2020-12-22 20:28:37,216 : INFO : EPOCH 18 - PROGRESS: at 18.73% examples, 314748 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:38,227 : INFO : EPOCH 18 - PROGRESS: at 42.45% examples, 369837 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:39,249 : INFO : EPOCH 18 - PROGRESS: at 62.15% examples, 363674 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:40,249 : INFO : EPOCH 18 - PROGRESS: at 84.47% examples, 378174 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:40,800 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:40,803 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:40,816 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:40,826 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:40,832 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:40,842 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:40,856 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:40,884 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:40,889 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:40,892 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:40,896 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:40,900 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:40,901 : INFO : EPOCH - 18 : training on 1951575 raw words (1854725 effective words) took 4.8s, 387243 effective words/s
# 2020-12-22 20:28:42,036 : INFO : EPOCH 19 - PROGRESS: at 18.72% examples, 308808 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:43,044 : INFO : EPOCH 19 - PROGRESS: at 41.43% examples, 357609 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:44,092 : INFO : EPOCH 19 - PROGRESS: at 63.13% examples, 364459 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:45,099 : INFO : EPOCH 19 - PROGRESS: at 85.45% examples, 378012 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:45,568 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:45,589 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:45,612 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:45,618 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:45,623 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:45,627 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:45,634 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:45,653 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:45,662 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:45,664 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:45,666 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:45,678 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:45,680 : INFO : EPOCH - 19 : training on 1951575 raw words (1854466 effective words) took 4.8s, 388722 effective words/s
# 2020-12-22 20:28:46,736 : INFO : EPOCH 20 - PROGRESS: at 18.72% examples, 332361 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:47,752 : INFO : EPOCH 20 - PROGRESS: at 40.35% examples, 361080 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:48,778 : INFO : EPOCH 20 - PROGRESS: at 63.13% examples, 375563 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:49,787 : INFO : EPOCH 20 - PROGRESS: at 85.45% examples, 386466 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:50,266 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:50,269 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:50,276 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:50,285 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:50,289 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:50,308 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:50,317 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:50,341 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:50,349 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:50,355 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:50,360 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:50,371 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:50,373 : INFO : EPOCH - 20 : training on 1951575 raw words (1854713 effective words) took 4.7s, 396013 effective words/s
# 2020-12-22 20:28:51,404 : INFO : EPOCH 21 - PROGRESS: at 18.72% examples, 340348 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:52,420 : INFO : EPOCH 21 - PROGRESS: at 39.82% examples, 360658 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:53,445 : INFO : EPOCH 21 - PROGRESS: at 56.81% examples, 341635 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:54,458 : INFO : EPOCH 21 - PROGRESS: at 77.04% examples, 349254 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:55,368 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:28:55,404 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:28:55,411 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:28:55,427 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:28:55,432 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:28:55,447 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:28:55,451 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:28:55,475 : INFO : EPOCH 21 - PROGRESS: at 98.03% examples, 357291 words/s, in_qsize 4, out_qsize 1
# 2020-12-22 20:28:55,477 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:28:55,483 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:28:55,489 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:28:55,490 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:28:55,502 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:28:55,503 : INFO : EPOCH - 21 : training on 1951575 raw words (1854677 effective words) took 5.1s, 362169 effective words/s
# 2020-12-22 20:28:56,627 : INFO : EPOCH 22 - PROGRESS: at 18.72% examples, 311826 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:57,632 : INFO : EPOCH 22 - PROGRESS: at 40.37% examples, 351297 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:28:58,633 : INFO : EPOCH 22 - PROGRESS: at 60.02% examples, 353474 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:28:59,634 : INFO : EPOCH 22 - PROGRESS: at 80.88% examples, 363620 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:00,320 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:00,328 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:00,353 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:00,357 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:00,359 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:00,377 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:29:00,405 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:29:00,411 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:29:00,414 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:29:00,423 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:29:00,425 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:29:00,435 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:29:00,436 : INFO : EPOCH - 22 : training on 1951575 raw words (1854790 effective words) took 4.9s, 376586 effective words/s
# 2020-12-22 20:29:01,490 : INFO : EPOCH 23 - PROGRESS: at 18.72% examples, 333284 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:02,490 : INFO : EPOCH 23 - PROGRESS: at 40.90% examples, 368857 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:03,557 : INFO : EPOCH 23 - PROGRESS: at 62.15% examples, 366774 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:29:04,615 : INFO : EPOCH 23 - PROGRESS: at 79.86% examples, 355040 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:05,595 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:05,603 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:05,610 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:05,615 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:05,630 : INFO : EPOCH 23 - PROGRESS: at 96.50% examples, 345501 words/s, in_qsize 7, out_qsize 1
# 2020-12-22 20:29:05,632 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:05,644 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:29:05,645 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:29:05,669 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:29:05,674 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:29:05,681 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:29:05,684 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:29:05,692 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:29:05,693 : INFO : EPOCH - 23 : training on 1951575 raw words (1854254 effective words) took 5.2s, 353399 effective words/s
# 2020-12-22 20:29:06,721 : INFO : EPOCH 24 - PROGRESS: at 18.73% examples, 341085 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:07,824 : INFO : EPOCH 24 - PROGRESS: at 43.44% examples, 377784 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:08,912 : INFO : EPOCH 24 - PROGRESS: at 61.67% examples, 352590 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:29:09,945 : INFO : EPOCH 24 - PROGRESS: at 81.93% examples, 357763 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:10,489 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:10,492 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:10,504 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:10,508 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:10,521 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:10,543 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:29:10,559 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:29:10,574 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:29:10,579 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:29:10,580 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:29:10,583 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:29:10,594 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:29:10,595 : INFO : EPOCH - 24 : training on 1951575 raw words (1854699 effective words) took 4.9s, 379033 effective words/s
# 2020-12-22 20:29:11,631 : INFO : EPOCH 25 - PROGRESS: at 20.23% examples, 366274 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:12,645 : INFO : EPOCH 25 - PROGRESS: at 43.44% examples, 392573 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:13,661 : INFO : EPOCH 25 - PROGRESS: at 67.64% examples, 407153 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:14,743 : INFO : EPOCH 25 - PROGRESS: at 91.90% examples, 412235 words/s, in_qsize 16, out_qsize 0
# 2020-12-22 20:29:14,876 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:14,900 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:14,908 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:14,920 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:14,923 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:14,929 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:29:14,941 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:29:14,962 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:29:14,966 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:29:14,969 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:29:14,974 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:29:14,985 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:29:14,986 : INFO : EPOCH - 25 : training on 1951575 raw words (1854727 effective words) took 4.4s, 423158 effective words/s
# 2020-12-22 20:29:16,004 : INFO : EPOCH 26 - PROGRESS: at 18.73% examples, 344927 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:17,118 : INFO : EPOCH 26 - PROGRESS: at 43.44% examples, 377871 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:18,121 : INFO : EPOCH 26 - PROGRESS: at 65.07% examples, 383253 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:19,138 : INFO : EPOCH 26 - PROGRESS: at 85.98% examples, 384588 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:29:19,519 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:19,542 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:19,546 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:19,555 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:19,570 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:19,578 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:29:19,589 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:29:19,615 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:29:19,623 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:29:19,625 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:29:19,627 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:29:19,639 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:29:19,640 : INFO : EPOCH - 26 : training on 1951575 raw words (1854720 effective words) took 4.6s, 399295 effective words/s
# 2020-12-22 20:29:20,673 : INFO : EPOCH 27 - PROGRESS: at 18.74% examples, 339495 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:21,697 : INFO : EPOCH 27 - PROGRESS: at 41.43% examples, 372845 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:29:22,699 : INFO : EPOCH 27 - PROGRESS: at 63.62% examples, 383451 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:23,708 : INFO : EPOCH 27 - PROGRESS: at 87.00% examples, 397079 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:24,079 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:24,085 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:24,114 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:24,117 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:24,128 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:24,129 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:29:24,145 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:29:24,169 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:29:24,171 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:29:24,180 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:29:24,185 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:29:24,193 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:29:24,194 : INFO : EPOCH - 27 : training on 1951575 raw words (1854471 effective words) took 4.5s, 407968 effective words/s
# 2020-12-22 20:29:25,219 : INFO : EPOCH 28 - PROGRESS: at 20.23% examples, 370373 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:26,229 : INFO : EPOCH 28 - PROGRESS: at 43.44% examples, 395832 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:27,240 : INFO : EPOCH 28 - PROGRESS: at 67.08% examples, 406829 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:29:28,263 : INFO : EPOCH 28 - PROGRESS: at 87.00% examples, 397112 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:29:28,650 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:29:28,658 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:29:28,671 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:29:28,687 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:29:28,695 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:29:28,723 : INFO : worker thread finished; awaiting finish of 6 more threads
# ...
# 2020-12-22 20:30:33,607 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:30:33,608 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:30:33,619 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:30:33,621 : INFO : EPOCH - 41 : training on 1951575 raw words (1854844 effective words) took 4.8s, 384718 effective words/s
# 2020-12-22 20:30:34,631 : INFO : EPOCH 42 - PROGRESS: at 19.70% examples, 365886 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:35,664 : INFO : EPOCH 42 - PROGRESS: at 43.44% examples, 393854 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:30:36,670 : INFO : EPOCH 42 - PROGRESS: at 66.60% examples, 403218 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:37,673 : INFO : EPOCH 42 - PROGRESS: at 87.00% examples, 398600 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:38,065 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:30:38,074 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:30:38,082 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:30:38,087 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:30:38,100 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:30:38,112 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:30:38,117 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:30:38,142 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:30:38,149 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:30:38,151 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:30:38,154 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:30:38,161 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:30:38,162 : INFO : EPOCH - 42 : training on 1951575 raw words (1854614 effective words) took 4.5s, 409110 effective words/s
# 2020-12-22 20:30:39,177 : INFO : EPOCH 43 - PROGRESS: at 19.22% examples, 355379 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:30:40,225 : INFO : EPOCH 43 - PROGRESS: at 43.44% examples, 390562 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:41,241 : INFO : EPOCH 43 - PROGRESS: at 67.64% examples, 405732 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:42,243 : INFO : EPOCH 43 - PROGRESS: at 88.46% examples, 402971 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:42,513 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:30:42,522 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:30:42,546 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:30:42,557 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:30:42,559 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:30:42,565 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:30:42,575 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:30:42,598 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:30:42,605 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:30:42,607 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:30:42,613 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:30:42,622 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:30:42,623 : INFO : EPOCH - 43 : training on 1951575 raw words (1854783 effective words) took 4.5s, 416664 effective words/s
# 2020-12-22 20:30:43,672 : INFO : EPOCH 44 - PROGRESS: at 18.72% examples, 334655 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:44,734 : INFO : EPOCH 44 - PROGRESS: at 43.44% examples, 381380 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:45,756 : INFO : EPOCH 44 - PROGRESS: at 67.16% examples, 395484 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:46,759 : INFO : EPOCH 44 - PROGRESS: at 90.48% examples, 406668 words/s, in_qsize 19, out_qsize 0
# 2020-12-22 20:30:47,003 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:30:47,012 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:30:47,017 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:30:47,023 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:30:47,031 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:30:47,057 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:30:47,063 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:30:47,091 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:30:47,093 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:30:47,094 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:30:47,101 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:30:47,107 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:30:47,108 : INFO : EPOCH - 44 : training on 1951575 raw words (1854738 effective words) took 4.5s, 414409 effective words/s
# 2020-12-22 20:30:48,116 : INFO : EPOCH 45 - PROGRESS: at 19.70% examples, 366869 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:49,127 : INFO : EPOCH 45 - PROGRESS: at 41.39% examples, 380078 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:30:50,154 : INFO : EPOCH 45 - PROGRESS: at 54.60% examples, 332296 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:51,172 : INFO : EPOCH 45 - PROGRESS: at 73.03% examples, 332596 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:52,202 : INFO : EPOCH 45 - PROGRESS: at 91.88% examples, 335648 words/s, in_qsize 16, out_qsize 0
# 2020-12-22 20:30:52,300 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:30:52,305 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:30:52,312 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:30:52,326 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:30:52,330 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:30:52,352 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:30:52,365 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:30:52,399 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:30:52,401 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:30:52,404 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:30:52,405 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:30:52,416 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:30:52,417 : INFO : EPOCH - 45 : training on 1951575 raw words (1854736 effective words) took 5.3s, 349927 effective words/s
# 2020-12-22 20:30:53,455 : INFO : EPOCH 46 - PROGRESS: at 18.72% examples, 338073 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:54,516 : INFO : EPOCH 46 - PROGRESS: at 43.44% examples, 383569 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:55,517 : INFO : EPOCH 46 - PROGRESS: at 65.59% examples, 390473 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:56,528 : INFO : EPOCH 46 - PROGRESS: at 88.00% examples, 397589 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:30:56,829 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:30:56,845 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:30:56,857 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:30:56,867 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:30:56,870 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:30:56,896 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:30:56,903 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:30:56,917 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:30:56,928 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:30:56,931 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:30:56,933 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:30:56,944 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:30:56,945 : INFO : EPOCH - 46 : training on 1951575 raw words (1854567 effective words) took 4.5s, 410349 effective words/s
# 2020-12-22 20:30:57,979 : INFO : EPOCH 47 - PROGRESS: at 18.72% examples, 339498 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:30:59,051 : INFO : EPOCH 47 - PROGRESS: at 43.44% examples, 382536 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:00,063 : INFO : EPOCH 47 - PROGRESS: at 67.08% examples, 397561 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:01,073 : INFO : EPOCH 47 - PROGRESS: at 91.40% examples, 412056 words/s, in_qsize 17, out_qsize 0
# 2020-12-22 20:31:01,286 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:31:01,301 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:31:01,302 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:31:01,315 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:31:01,320 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:31:01,332 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:31:01,355 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:31:01,380 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:31:01,384 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:31:01,390 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:31:01,393 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:31:01,398 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:31:01,399 : INFO : EPOCH - 47 : training on 1951575 raw words (1854627 effective words) took 4.4s, 417252 effective words/s
# 2020-12-22 20:31:02,416 : INFO : EPOCH 48 - PROGRESS: at 20.69% examples, 382560 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:03,460 : INFO : EPOCH 48 - PROGRESS: at 44.05% examples, 395209 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:04,472 : INFO : EPOCH 48 - PROGRESS: at 68.56% examples, 412386 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:05,520 : INFO : EPOCH 48 - PROGRESS: at 85.98% examples, 387410 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:05,881 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:31:05,898 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:31:05,902 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:31:05,927 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:31:05,933 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:31:05,941 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:31:05,951 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:31:05,985 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:31:05,987 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:31:05,989 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:31:05,990 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:31:06,002 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:31:06,003 : INFO : EPOCH - 48 : training on 1951575 raw words (1854537 effective words) took 4.6s, 403559 effective words/s
# 2020-12-22 20:31:07,067 : INFO : EPOCH 49 - PROGRESS: at 18.72% examples, 329879 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:08,125 : INFO : EPOCH 49 - PROGRESS: at 43.44% examples, 379501 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:09,168 : INFO : EPOCH 49 - PROGRESS: at 68.12% examples, 397527 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:10,176 : INFO : EPOCH 49 - PROGRESS: at 85.00% examples, 378137 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:10,656 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:31:10,676 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:31:10,681 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:31:10,695 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:31:10,707 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:31:10,714 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:31:10,716 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:31:10,743 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:31:10,751 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:31:10,758 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:31:10,761 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:31:10,770 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:31:10,771 : INFO : EPOCH - 49 : training on 1951575 raw words (1855074 effective words) took 4.8s, 389832 effective words/s
# 2020-12-22 20:31:11,819 : INFO : EPOCH 50 - PROGRESS: at 18.72% examples, 334629 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:31:12,850 : INFO : EPOCH 50 - PROGRESS: at 35.30% examples, 314260 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:13,860 : INFO : EPOCH 50 - PROGRESS: at 51.00% examples, 306244 words/s, in_qsize 24, out_qsize 0
# 2020-12-22 20:31:14,864 : INFO : EPOCH 50 - PROGRESS: at 67.16% examples, 302475 words/s, in_qsize 23, out_qsize 0
# 2020-12-22 20:31:15,869 : INFO : EPOCH 50 - PROGRESS: at 88.85% examples, 324177 words/s, in_qsize 22, out_qsize 0
# 2020-12-22 20:31:16,119 : INFO : worker thread finished; awaiting finish of 11 more threads
# 2020-12-22 20:31:16,127 : INFO : worker thread finished; awaiting finish of 10 more threads
# 2020-12-22 20:31:16,147 : INFO : worker thread finished; awaiting finish of 9 more threads
# 2020-12-22 20:31:16,154 : INFO : worker thread finished; awaiting finish of 8 more threads
# 2020-12-22 20:31:16,156 : INFO : worker thread finished; awaiting finish of 7 more threads
# 2020-12-22 20:31:16,167 : INFO : worker thread finished; awaiting finish of 6 more threads
# 2020-12-22 20:31:16,189 : INFO : worker thread finished; awaiting finish of 5 more threads
# 2020-12-22 20:31:16,219 : INFO : worker thread finished; awaiting finish of 4 more threads
# 2020-12-22 20:31:16,222 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-22 20:31:16,225 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-22 20:31:16,229 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-22 20:31:16,234 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-22 20:31:16,235 : INFO : EPOCH - 50 : training on 1951575 raw words (1854425 effective words) took 5.5s, 339936 effective words/s
# 2020-12-22 20:31:16,236 : INFO : training on a 97578750 raw words (92734091 effective words) took 247.6s, 374554 effective words/s

# %%
ranks = []
second_ranks = []
for doc_id in tqdm(range(len(train_corpus))):
    inferred_vector = model.infer_vector(train_corpus[doc_id].words)
    sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))
    rank = [docid for docid, sim in sims].index(doc_id)
    ranks.append(rank)

    second_ranks.append(sims[1])
# Out:
#   0%|                                                                                        | 0/25000 [00:00<?, ?it/s]2020-12-22 13:28:24,619 : INFO : precomputing L2-norms of doc weight vectors
# 100%|████████████████████████████████████████████████████████████████████████████| 25000/25000 [28:45<00:00, 14.49it/s]

# %%
similar_ratings = {}
for doc_id in tqdm(range(len(train_corpus))):
    inferred_vector = model.infer_vector(train_corpus[doc_id].words)
    sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))
    for i in range(10):
        if train_corpus[sims[doc_id][0]].rating[0] in similar_ratings:
            similar_ratings[train_corpus[sims[doc_id][0]].rating[0]] = [train_corpus[sims[i][0]].rating[0]]
        else:
            similar_ratings[train_corpus[sims[doc_id][0]].rating[0]] += [train_corpus[sims[i][0]].rating[0]]
# Out:
#   0%|                                                                                        | 0/16750 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-c6e92d4b8e9d> in <module>
#       7             similar_ratings[train_corpus[sims[doc_id][0]].rating[0]] = [train_corpus[sims[i][0]].rating[0]]
#       8         else:
# ----> 9             similar_ratings[train_corpus[sims[doc_id][0]].rating[0]] += [train_corpus[sims[i][0]].rating[0]]
#
# KeyError: '1'

# %%
train_corpus[s[4][0]].rating[0]
# Out:
# '1'

# %%
counter = collections.Counter(ranks)
print(counter)
# Out:
# Counter({0: 24888, 1: 106, 2: 6})

# %%
# Pick a random document from the test corpus and infer a vector from the model
doc_id = random.randint(0, len(train_corpus) - 1)
iv = model.infer_vector(train_corpus[doc_id].words)
s = model.docvecs.most_similar([iv], topn=len(model.docvecs))
train_corpus[s[12345][0]].rating[0]
# Out:
# '8'

# %%
# Pick a random document from the test corpus and infer a vector from the model
doc_id = random.randint(0, len(train_corpus) - 1)
iv = model.infer_vector(train_corpus[doc_id].words)
s = model.docvecs.most_similar([iv], topn=len(model.docvecs))

# Compare and print the most/median/least similar documents from the train corpus
print(f'Test Document {(doc_id, " ".join(train_corpus[doc_id].rating))}: «{" ".join(train_corpus[doc_id].words)}»\n')
# print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)
# for label, index in [('MOST', 1), ('MEDIAN', len(s)//2), ('LEAST', len(s) - 1)]:
#     print(f'{label} : {(" ".join(train_corpus[s[index][0]].rating))} : {s[index][1]} - {(" ".join(train_corpus[s[index][0]].words))}\n')
for i in len(s):
    print(train_corpus)
# Out:
# Test Document (6667, '8'): «magnum opus swedish king crap matshelge olsson seldom movie magnitude made sweden truly stands one amazing achievements swedish film date pays things russian nuclear scientist markov wants defect sweden plans ruined russian military kidnap tell arrived sweden trickery way seeing markov continues work nuclear physics revolutionize energy supply whole planet cia however bent getting markov west send ninja liberate practice swedish actors speaking english something matshelge perfected later works cheap bmovie feeling creates probably unmatched performance besides well action standard directtovideo style machine guns firing huge clouds smoke thousands russians dying people running around black ninja suits trying hide snow really stands though insanely poor way fighting scenes choreographed say ninja title expect martial arts expect close combat maybe two three scenes actual martial arts movie hilarious bad lack words describe ninjas moved slower hearts would stop course whole movie ends bang indicates specialeffects budget consisting four foodstamps mcdonald voucher verdict instant classic course never movie made obviously meant consumed along huge amounts alcohol ultimate party movie insert video laugh one realize movies like made film history therefore rating entertainment quality accents»
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-6aaf76d1e8a5> in <module>
#       9 # for label, index in [('MOST', 1), ('MEDIAN', len(s)//2), ('LEAST', len(s) - 1)]:
#      10 #     print(f'{label} : {(" ".join(train_corpus[s[index][0]].rating))} : {s[index][1]} - {(" ".join(train_corpus[s[index][0]].words))}\n')
# ---> 11 for i in len(s):
#      12     print(f' {(" ".join(train_corpus[s[index]].rating))}')
#
# TypeError: 'int' object is not iterable

# %%
def vector_for_learning(model, input_docs):
    sents = input_docs
    targets, feature_vectors = zip(*[(doc.tags[0], model.infer_vector(doc.words, steps=20)) for doc in tqdm(sents)])
    return targets, feature_vectors

y_train, X_train = vector_for_learning(model_dbow, train_documents)
y_test, X_test = vector_for_learning(model_dbow, test_documents)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2999/2999 [00:46<00:00, 63.82it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 2001/2001 [00:29<00:00, 67.45it/s]

# %%
logreg = LogisticRegression(n_jobs=1, C=1e5)
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
# Out:
# d:\actual_softwares\python3.8.x\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print('Testing accuracy for movie plots%s' % accuracy_score(y_test, y_pred))
print('Testing F1 score for movie plots: {}'.format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# Testing accuracy for movie plots0.3103448275862069
# Testing F1 score for movie plots: 0.3135941911201832
